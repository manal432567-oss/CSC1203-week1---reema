# %% [markdown]
# <a href="https://colab.research.google.com/github/manal432567-oss/CSC1203-week1---reema/blob/main/lab_week1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This pogram # This program prints a welcome message
print("Welcome to Python Programming!")

# Printing my name and course on separate lines
print("Reema")
print("Computer Science")
# Out:
# Welcome to Python Programming!
# Reema
# Computer Science

# %%
# Declaring variables with different data types

student_name = "Reema"              # string
age = 18                            # integer
gpa = 4.2                           # float

subjects = ["Python", "Java", "Math"]   # list

student_info = {                   # dictionary
    "id": 4312345678,
    "year": 1
}

skills = {"Python", "Problem Solving"}  # set

is_enrolled = True                 # boolean
graduation_date = None             # None type


# Printing each variable and its data type

print(student_name, type(student_name))
print(age, type(age))
print(gpa, type(gpa))
print(subjects, type(subjects))
print(student_info, type(student_info))
print(skills, type(skills))
print(is_enrolled, type(is_enrolled))
print(graduation_date, type(graduation_date))
# Out:
# Reema <class 'str'>
# 18 <class 'int'>
# 4.2 <class 'float'>
# ['Python', 'Java', 'Math'] <class 'list'>
# {'id': 4312345678, 'year': 1} <class 'dict'>
# {'Python', 'Problem Solving'} <class 'set'>
# True <class 'bool'>
# None <class 'NoneType'>
